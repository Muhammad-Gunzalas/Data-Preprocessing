# %%
import pandas as pd

# %%
data=pd.read_csv('Secondary-sales-report-20180406-data.csv')

# %%
data
# Out:
#       Region  Loc      CATEGORY            BRAND       PACK       RTM Period  \
# 0     Center  FSD  ENERGY DRINK  MONSTER PREMIUM  355ml CAN    Direct    YTD
# 1     Center  FSD  ENERGY DRINK  MONSTER PREMIUM  355ml CAN  Indirect    MTD
# 2     Center  FSD  ENERGY DRINK  MONSTER PREMIUM  355ml CAN  Indirect  TODAY
# 3     Center  FSD  ENERGY DRINK  MONSTER PREMIUM  355ml CAN  Indirect    WTD
# 4     Center  FSD  ENERGY DRINK  MONSTER PREMIUM  355ml CAN  Indirect    YTD
# ...      ...  ...           ...              ...        ...       ...    ...
# 5432     NaN  NaN           NaN              NaN        NaN       NaN    NaN
# 5433     NaN  NaN           NaN              NaN        NaN       NaN    NaN
# 5434     NaN  NaN           NaN              NaN        NaN       NaN    NaN
# 5435     NaN  NaN           NaN              NaN        NaN       NaN    NaN
# 5436     NaN  NaN           NaN              NaN        NaN       NaN    NaN
#
# ...

# %%
data.head()
# Out:
#    Region  Loc      CATEGORY            BRAND       PACK       RTM Period  \
# 0  Center  FSD  ENERGY DRINK  MONSTER PREMIUM  355ml CAN    Direct    YTD
# 1  Center  FSD  ENERGY DRINK  MONSTER PREMIUM  355ml CAN  Indirect    MTD
# 2  Center  FSD  ENERGY DRINK  MONSTER PREMIUM  355ml CAN  Indirect  TODAY
# 3  Center  FSD  ENERGY DRINK  MONSTER PREMIUM  355ml CAN  Indirect    WTD
# 4  Center  FSD  ENERGY DRINK  MONSTER PREMIUM  355ml CAN  Indirect    YTD
#
#    ACT-2017  ACT-2018      BP-2018  Unnamed: 10  Unnamed: 11
# 0       NaN    24.009          NaN          NaN          NaN
# 1       NaN    64.521    99.694975          NaN          NaN
# 2       NaN       NaN    21.587125          NaN          NaN
# 3       NaN    64.521    99.694975          NaN          NaN
# 4       NaN   219.817  2026.414181          NaN          NaN

# %%
data_0=data[data['Period']=='TODAY']

# %%
data_0
# Out:
#       Region  Loc      CATEGORY              BRAND         PACK       RTM  \
# 2     Center  FSD  ENERGY DRINK    MONSTER PREMIUM    355ml CAN  Indirect
# 6     Center  FSD  ENERGY DRINK             Mutant    500ml PET  Indirect
# 10    Center  FSD         JUICE  CAPPY JOOSI APPLE  200ml TETRA    Direct
# 14    Center  FSD         JUICE  CAPPY JOOSI APPLE  200ml TETRA  Indirect
# 18    Center  FSD         JUICE  CAPPY JOOSI MANGO  200ml TETRA    Direct
# ...      ...  ...           ...                ...          ...       ...
# 5035   South  RYK     SPARKLING        SPRITE ZERO    500ml PET  Indirect
# 5039   South  RYK         WATER             DASANI   1500ml PET    Direct
# 5043   South  RYK         WATER             DASANI   1500ml PET  Indirect
# 5050   South  RYK         WATER             KINLEY   1500ml PET  Indirect
# 5054   South  RYK         WATER             KINLEY    500ml PET  Indirect
#
#      Period  ACT-2017  ACT-2018      BP-2018  Unnamed: 10  Unnamed: 11
# ...

# %%
data_0.drop(['Region'],axis=1)
# Out:
#       Loc      CATEGORY              BRAND         PACK       RTM Period  \
# 2     FSD  ENERGY DRINK    MONSTER PREMIUM    355ml CAN  Indirect  TODAY
# 6     FSD  ENERGY DRINK             Mutant    500ml PET  Indirect  TODAY
# 10    FSD         JUICE  CAPPY JOOSI APPLE  200ml TETRA    Direct  TODAY
# 14    FSD         JUICE  CAPPY JOOSI APPLE  200ml TETRA  Indirect  TODAY
# 18    FSD         JUICE  CAPPY JOOSI MANGO  200ml TETRA    Direct  TODAY
# ...   ...           ...                ...          ...       ...    ...
# 5035  RYK     SPARKLING        SPRITE ZERO    500ml PET  Indirect  TODAY
# 5039  RYK         WATER             DASANI   1500ml PET    Direct  TODAY
# 5043  RYK         WATER             DASANI   1500ml PET  Indirect  TODAY
# 5050  RYK         WATER             KINLEY   1500ml PET  Indirect  TODAY
# 5054  RYK         WATER             KINLEY    500ml PET  Indirect  TODAY
#
#       ACT-2017  ACT-2018      BP-2018  Unnamed: 10  Unnamed: 11
# ...

# %%
data_1=data_0.drop(['Region'],axis=1).copy()

# %%
data_1
# Out:
#       Loc      CATEGORY              BRAND         PACK       RTM Period  \
# 2     FSD  ENERGY DRINK    MONSTER PREMIUM    355ml CAN  Indirect  TODAY
# 6     FSD  ENERGY DRINK             Mutant    500ml PET  Indirect  TODAY
# 10    FSD         JUICE  CAPPY JOOSI APPLE  200ml TETRA    Direct  TODAY
# 14    FSD         JUICE  CAPPY JOOSI APPLE  200ml TETRA  Indirect  TODAY
# 18    FSD         JUICE  CAPPY JOOSI MANGO  200ml TETRA    Direct  TODAY
# ...   ...           ...                ...          ...       ...    ...
# 5035  RYK     SPARKLING        SPRITE ZERO    500ml PET  Indirect  TODAY
# 5039  RYK         WATER             DASANI   1500ml PET    Direct  TODAY
# 5043  RYK         WATER             DASANI   1500ml PET  Indirect  TODAY
# 5050  RYK         WATER             KINLEY   1500ml PET  Indirect  TODAY
# 5054  RYK         WATER             KINLEY    500ml PET  Indirect  TODAY
#
#       ACT-2017  ACT-2018      BP-2018  Unnamed: 10  Unnamed: 11
# ...

# %%
split_data=data_1['PACK'].str.split(' ',n=1,expand=True)
split_data

# %%
data_1['Packsize']=split_data[0]
data_1['Package']=split_data[1]

# %%
data_1.drop(['PACK'],axis=1)
# Out:
#       Loc      CATEGORY              BRAND       RTM Period  ACT-2017  \
# 2     FSD  ENERGY DRINK    MONSTER PREMIUM  Indirect  TODAY       NaN
# 6     FSD  ENERGY DRINK             Mutant  Indirect  TODAY       NaN
# 10    FSD         JUICE  CAPPY JOOSI APPLE    Direct  TODAY       NaN
# 14    FSD         JUICE  CAPPY JOOSI APPLE  Indirect  TODAY       NaN
# 18    FSD         JUICE  CAPPY JOOSI MANGO    Direct  TODAY       NaN
# ...   ...           ...                ...       ...    ...       ...
# 5035  RYK     SPARKLING        SPRITE ZERO  Indirect  TODAY     3.171
# 5039  RYK         WATER             DASANI    Direct  TODAY       NaN
# 5043  RYK         WATER             DASANI  Indirect  TODAY       NaN
# 5050  RYK         WATER             KINLEY  Indirect  TODAY   697.408
# 5054  RYK         WATER             KINLEY  Indirect  TODAY   257.875
#
#       ACT-2018      BP-2018  Unnamed: 10  Unnamed: 11 Packsize Package
# ...

# %%
data_2=data_1.drop(['PACK'],axis=1).copy()

# %%
data_2
# Out:
#       Loc      CATEGORY              BRAND       RTM Period  ACT-2017  \
# 2     FSD  ENERGY DRINK    MONSTER PREMIUM  Indirect  TODAY       NaN
# 6     FSD  ENERGY DRINK             Mutant  Indirect  TODAY       NaN
# 10    FSD         JUICE  CAPPY JOOSI APPLE    Direct  TODAY       NaN
# 14    FSD         JUICE  CAPPY JOOSI APPLE  Indirect  TODAY       NaN
# 18    FSD         JUICE  CAPPY JOOSI MANGO    Direct  TODAY       NaN
# ...   ...           ...                ...       ...    ...       ...
# 5035  RYK     SPARKLING        SPRITE ZERO  Indirect  TODAY     3.171
# 5039  RYK         WATER             DASANI    Direct  TODAY       NaN
# 5043  RYK         WATER             DASANI  Indirect  TODAY       NaN
# 5050  RYK         WATER             KINLEY  Indirect  TODAY   697.408
# 5054  RYK         WATER             KINLEY  Indirect  TODAY   257.875
#
#       ACT-2018      BP-2018  Unnamed: 10  Unnamed: 11 Packsize Package
# ...

# %%
data_2.insert(loc=1,column='Year',value='2018')

# %%
data_2
# Out:
#       Loc  Year      CATEGORY              BRAND       RTM Period  ACT-2017  \
# 2     FSD  2018  ENERGY DRINK    MONSTER PREMIUM  Indirect  TODAY       NaN
# 6     FSD  2018  ENERGY DRINK             Mutant  Indirect  TODAY       NaN
# 10    FSD  2018         JUICE  CAPPY JOOSI APPLE    Direct  TODAY       NaN
# 14    FSD  2018         JUICE  CAPPY JOOSI APPLE  Indirect  TODAY       NaN
# 18    FSD  2018         JUICE  CAPPY JOOSI MANGO    Direct  TODAY       NaN
# ...   ...   ...           ...                ...       ...    ...       ...
# 5035  RYK  2018     SPARKLING        SPRITE ZERO  Indirect  TODAY     3.171
# 5039  RYK  2018         WATER             DASANI    Direct  TODAY       NaN
# 5043  RYK  2018         WATER             DASANI  Indirect  TODAY       NaN
# 5050  RYK  2018         WATER             KINLEY  Indirect  TODAY   697.408
# 5054  RYK  2018         WATER             KINLEY  Indirect  TODAY   257.875
#
# ...

# %%
data_2.insert(loc=1,column='Month',value='Apr')

# %%
data_2
# Out:
#       Loc Month  Year      CATEGORY              BRAND       RTM Period  \
# 2     FSD   Apr  2018  ENERGY DRINK    MONSTER PREMIUM  Indirect  TODAY
# 6     FSD   Apr  2018  ENERGY DRINK             Mutant  Indirect  TODAY
# 10    FSD   Apr  2018         JUICE  CAPPY JOOSI APPLE    Direct  TODAY
# 14    FSD   Apr  2018         JUICE  CAPPY JOOSI APPLE  Indirect  TODAY
# 18    FSD   Apr  2018         JUICE  CAPPY JOOSI MANGO    Direct  TODAY
# ...   ...   ...   ...           ...                ...       ...    ...
# 5035  RYK   Apr  2018     SPARKLING        SPRITE ZERO  Indirect  TODAY
# 5039  RYK   Apr  2018         WATER             DASANI    Direct  TODAY
# 5043  RYK   Apr  2018         WATER             DASANI  Indirect  TODAY
# 5050  RYK   Apr  2018         WATER             KINLEY  Indirect  TODAY
# 5054  RYK   Apr  2018         WATER             KINLEY  Indirect  TODAY
#
#       ACT-2017  ACT-2018      BP-2018  Unnamed: 10  Unnamed: 11 Packsize  \
# ...

# %%
data_2.insert(loc=1,column='Day',value='6')

# %%
data_2
# Out:
#       Loc Day Month  Year      CATEGORY              BRAND       RTM Period  \
# 2     FSD   6   Apr  2018  ENERGY DRINK    MONSTER PREMIUM  Indirect  TODAY
# 6     FSD   6   Apr  2018  ENERGY DRINK             Mutant  Indirect  TODAY
# 10    FSD   6   Apr  2018         JUICE  CAPPY JOOSI APPLE    Direct  TODAY
# 14    FSD   6   Apr  2018         JUICE  CAPPY JOOSI APPLE  Indirect  TODAY
# 18    FSD   6   Apr  2018         JUICE  CAPPY JOOSI MANGO    Direct  TODAY
# ...   ...  ..   ...   ...           ...                ...       ...    ...
# 5035  RYK   6   Apr  2018     SPARKLING        SPRITE ZERO  Indirect  TODAY
# 5039  RYK   6   Apr  2018         WATER             DASANI    Direct  TODAY
# 5043  RYK   6   Apr  2018         WATER             DASANI  Indirect  TODAY
# 5050  RYK   6   Apr  2018         WATER             KINLEY  Indirect  TODAY
# 5054  RYK   6   Apr  2018         WATER             KINLEY  Indirect  TODAY
#
# ...

# %%
data_2.head()
# Out:
#     Loc Day Month  Year      CATEGORY              BRAND       RTM Period  \
# 2   FSD   6   Apr  2018  ENERGY DRINK    MONSTER PREMIUM  Indirect  TODAY
# 6   FSD   6   Apr  2018  ENERGY DRINK             Mutant  Indirect  TODAY
# 10  FSD   6   Apr  2018         JUICE  CAPPY JOOSI APPLE    Direct  TODAY
# 14  FSD   6   Apr  2018         JUICE  CAPPY JOOSI APPLE  Indirect  TODAY
# 18  FSD   6   Apr  2018         JUICE  CAPPY JOOSI MANGO    Direct  TODAY
#
#     ACT-2017  ACT-2018     BP-2018  Unnamed: 10  Unnamed: 11 Packsize Package
# 2        NaN       NaN   21.587125          NaN          NaN    355ml     CAN
# 6        NaN       NaN  188.182830          NaN          NaN    500ml     PET
# 10       NaN     8.454         NaN          NaN          NaN    200ml   TETRA
# 14       NaN       NaN   72.926403          NaN          NaN    200ml   TETRA
# 18       NaN    16.908         NaN          NaN          NaN    200ml   TETRA

# %%
data_3=data_2.copy()

# %%
data_3
# Out:
#       Loc Day Month  Year      CATEGORY              BRAND       RTM Period  \
# 2     FSD   6   Apr  2018  ENERGY DRINK    MONSTER PREMIUM  Indirect  TODAY
# 6     FSD   6   Apr  2018  ENERGY DRINK             Mutant  Indirect  TODAY
# 10    FSD   6   Apr  2018         JUICE  CAPPY JOOSI APPLE    Direct  TODAY
# 14    FSD   6   Apr  2018         JUICE  CAPPY JOOSI APPLE  Indirect  TODAY
# 18    FSD   6   Apr  2018         JUICE  CAPPY JOOSI MANGO    Direct  TODAY
# ...   ...  ..   ...   ...           ...                ...       ...    ...
# 5035  RYK   6   Apr  2018     SPARKLING        SPRITE ZERO  Indirect  TODAY
# 5039  RYK   6   Apr  2018         WATER             DASANI    Direct  TODAY
# 5043  RYK   6   Apr  2018         WATER             DASANI  Indirect  TODAY
# 5050  RYK   6   Apr  2018         WATER             KINLEY  Indirect  TODAY
# 5054  RYK   6   Apr  2018         WATER             KINLEY  Indirect  TODAY
#
# ...

# %%
data_4=data_3.reindex(columns=['Year','Month','Day','Loc','CATEGORY','BRAND','Packsize','Package','RTM','Period','ACT-2017','ACT-2018','BP-2018','Unnamed: 10','Unnamed: 11'])

# %%
data_4.head()
# Out:
#     Year Month Day  Loc      CATEGORY              BRAND Packsize Package  \
# 2   2018   Apr   6  FSD  ENERGY DRINK    MONSTER PREMIUM    355ml     CAN
# 6   2018   Apr   6  FSD  ENERGY DRINK             Mutant    500ml     PET
# 10  2018   Apr   6  FSD         JUICE  CAPPY JOOSI APPLE    200ml   TETRA
# 14  2018   Apr   6  FSD         JUICE  CAPPY JOOSI APPLE    200ml   TETRA
# 18  2018   Apr   6  FSD         JUICE  CAPPY JOOSI MANGO    200ml   TETRA
#
#          RTM Period  ACT-2017  ACT-2018     BP-2018  Unnamed: 10  Unnamed: 11
# 2   Indirect  TODAY       NaN       NaN   21.587125          NaN          NaN
# 6   Indirect  TODAY       NaN       NaN  188.182830          NaN          NaN
# 10    Direct  TODAY       NaN     8.454         NaN          NaN          NaN
# 14  Indirect  TODAY       NaN       NaN   72.926403          NaN          NaN
# 18    Direct  TODAY       NaN    16.908         NaN          NaN          NaN

# %%
data_4.rename(columns={'Loc':'Location'})
# Out:
#       Year Month Day Location      CATEGORY              BRAND Packsize  \
# 2     2018   Apr   6      FSD  ENERGY DRINK    MONSTER PREMIUM    355ml
# 6     2018   Apr   6      FSD  ENERGY DRINK             Mutant    500ml
# 10    2018   Apr   6      FSD         JUICE  CAPPY JOOSI APPLE    200ml
# 14    2018   Apr   6      FSD         JUICE  CAPPY JOOSI APPLE    200ml
# 18    2018   Apr   6      FSD         JUICE  CAPPY JOOSI MANGO    200ml
# ...    ...   ...  ..      ...           ...                ...      ...
# 5035  2018   Apr   6      RYK     SPARKLING        SPRITE ZERO    500ml
# 5039  2018   Apr   6      RYK         WATER             DASANI   1500ml
# 5043  2018   Apr   6      RYK         WATER             DASANI   1500ml
# 5050  2018   Apr   6      RYK         WATER             KINLEY   1500ml
# 5054  2018   Apr   6      RYK         WATER             KINLEY    500ml
#
#      Package       RTM Period  ACT-2017  ACT-2018      BP-2018  Unnamed: 10  \
# ...

# %%
file='RESULT 01 ETL.xlsx'

# %%
data_4.to_excel(file)

# %%
file
# Out:
# 'RESULT 01 ETL.xlsx'
